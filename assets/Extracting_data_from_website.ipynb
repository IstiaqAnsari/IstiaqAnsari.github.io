# %%
import numpy as np,os,pandas as pd,json

# %%
with open('publications.json') as f:
    data = json.load(f)

# %%
hm = hmm

# %%
i = 0
for x in hm.split('<p'):
    if('nbsp' not in x):
        try:
            date = x.split('<span')[1].split('>')[1].split('<')[0]
            news = x.split('</span><span')[1].split('>')[1].split('<')[0]
            print(i," DATA ",date,news)
            i+=1
        except:
            print("except")
# Out:
# except
# 0  DATA  Dec 2019:  mHealth Lab team as an R&amp;D partner of Sonavi Labs (Baltimore, USA) wins the MIT Solve - Tiger Challenge 2019!
# 1  DATA  Oct 2019:  Dr. Taufiq Hasan is invited to Technology Innovation Center, Johns Hopkins School of Medicine as a visiting scholar.
# except
# except
# except
# except
# except
# except
# 2  DATA  October 2018:  Dr. Alain Bernard Larbrique, Associate Professor, Johns Hopkins Bloomberg School of Public Health, joined mHealth Research Group as an Advisor.
# 3  DATA  September 2018:  Congratulations to Ahmed Imtiaz Humayun for receiving ISCA Student and Young Scientist Travel grant for attending INTERSPEECH 2018 in Hyderabad, India.
# 4  DATA  July 2018:  Congratulations to BME undergraduate students Farhana Islam and Mehnaz Urbee for winning
# 5  DATA  Paper on  nable fi

# %%
hmm = """
      <p id="u12038-3"><span id="u12038">Dec 2019: </span><span id="u12038-2">mHealth Lab team as an R&amp;D partner of Sonavi Labs (Baltimore, USA) wins the MIT Solve - Tiger Challenge 2019!</span></p>
      <p id="u12038-4">&nbsp;</p>
      <p id="u12038-7"><span id="u12038-5">Oct 2019: </span><span id="u12038-6">Dr. Taufiq Hasan is invited to Technology Innovation Center, Johns Hopkins School of Medicine as a visiting scholar.</span></p>
      <p id="u12038-8">&nbsp;</p>
      <p id="u12038-11"><span id="u12038-9">Sep 2019: </span>Dr. Taufiq Hasan is invited to serve as a mentor in the 2019 African Biomedical Engineering Consortium (ABEC) design school to be held in Kampala, Uganda.</p>
      <p id="u12038-12">&nbsp;</p>
      <p id="u12038-15"><span id="u12038-13">Aug 2019: </span>Former Research Assistant Ahmed Imtiaz is starting his PhD at RICE University.</p>
      <p id="u12038-16">&nbsp;</p>
      <p id="u12038-19"><span id="u12038-17">May 2019: </span>Dr. Taufiq Hasan is appointed as a chair of the Biomedical Signal Processing Informatics session at IEEE BHI 2019.</p>
      <p id="u12038-20">&nbsp;</p>
      <p id="u12038-23"><span id="u12038-21">May 2019: </span>Dr. Paul Nagy, Deputy Director of Johns Hopkins Medicine Technology Innovation Center and Associate Professor of Radiology and Radiological Science, joins mHealth Research Group as an Advisor.</p>
      <p id="u12038-24">&nbsp;</p>
      <p id="u12038-27"><span id="u12038-25">April 2019: </span>Congratulations to Anirban Chakraborty and Nusrat Binta Nizam on their success at the Johns Hopkins Design Competition 2019!</p>
      <p id="u12038-28">&nbsp;</p>
      <p id="u12038-31"><span id="u12038-29">April 2019: </span>Paper on Heart Sound Classification and X-Ray Image Compression accepted at IEEE BHI.</p>
      <p id="u12038-32">&nbsp;</p>
      <p id="u12038-35"><span id="u12038-33">October 2018: </span><span id="u12038-34">Dr. Alain Bernard Larbrique, Associate Professor, Johns Hopkins Bloomberg School of Public Health, joined mHealth Research Group as an Advisor.</span></p>
      <p id="u12038-36">&nbsp;</p>
      <p id="u12038-39"><span id="u12038-37">September 2018: </span><span id="u12038-38">Congratulations to Ahmed Imtiaz Humayun for receiving ISCA Student and Young Scientist Travel grant for attending INTERSPEECH 2018 in Hyderabad, India.</span></p>
      <p id="u12038-40">&nbsp;</p>
      <p class="mHealth-Links" id="u12038-46"><span id="u12038-41">July 2018:&nbsp; </span>Paper on <a class="nonblock" href="https://arxiv.org/pdf/1806.06506.pdf" target="_blank">Heart Sound Classification</a><span id="u12038-45"> system accepted in INTERSPEECH 2018 to be held in Hyderabad, India.</span></p>
      <p id="u12038-47">&nbsp;</p>
      <p class="mHealth-Links" id="u12038-57"><span id="u12038-48">July 2018: </span><span id="u12038-49">Congratulations to BME undergraduate students Farhana Islam and Mehnaz Urbee for winning </span><a class="nonblock" href="http://bme.buet.ac.bd/?p=1980">3rd place in the UBORA design competition 2018</a><span id="u12038-56">, Pisa, Italy.</span></p>
      <p id="u12038-58">&nbsp;</p>
      <p class="mHealth-Links" id="u12038-66">April 2018: <span id="u12038-60">Paper on </span><a class="nonblock" href="https://arxiv.org/abs/1806.05892"><span id="u12038-61">lear</span><span id="u12038-62">nable fi</span><span id="u12038-63">lterbanks for cardiac anomaly detection</span></a><span id="u12038-65"> accepted in IEEE Engineering in Medicine and Biology Conference (EMBC) 2018 to be held in Hawaii, USA.</span></p>
     </div>"""

# %% [markdown]
# # Extracting members name

# %%
file = open("MyFile.txt","a")

# %%
file.close()

# %%
findImage("Dr. Taufiq Hasan")
# Out:
# 'taufiq-crop-u2208.png'

# %%
def findImage(s):
    files = os.listdir("images")
    c = []
    for x in files:
        cc = 0
        for part in s.split():
            if(part.lower() in x.lower()):
                cc += 1
        c.append(cc)
    return files[c.index(max(c))]

# %%
hm = hmm
ok = {}
name = False
img = None
# file.write("name;designation;aff;img;link")
for i,x in enumerate(hm.split('<p')):
    s = x.split('>')[1].split('</p')[0]
    print(s)
# #     file.write(s+";")
    
    if("Dr." in s):
        name = True
    elif('Phd' in s):
        name = True
    if(name):
        img = findImage(s)
#         print(img)
        name = False
    if("ac.bd" in s):
#         file.write(img+";#;")
#         file.write("\n")
        name = True
        print(img)
        print()
    elif(s in "mHealth Research Group"):
        name = True
#         file.write(img+";#;")
#         file.write("\n")
        print(img)
        print()
    elif('nbsp' in s):
        name = True
        print(img)
        print()
# Out:
# <!-- column --
# OUR TEAM:
# Dr. Taufiq Hasan
# Assistant Professor, BME, BUET.
# Director, mHealth Research Group
# taufiq@bme.buet.ac.bd
# taufiq-crop-u2208.png
#
# Dr. Imamul Hassan Bhuiyan
# Professor & Head, BME, BUET.
# Professor, EEE, BUET.
# imamul@eee.buet.ac.bd
# imamul_sept19.jpg
#
# Asif Shahriyar
# Research Assistant
# mHealth Research Group
# asif shahriyar sushmit.jpg
#
# Istiaq Ansari
# Research Assistant
# mHealth Research Group
# istiaq_ansari.png
#
# Dr. Nawsabah Noor
# [MBBS, MRCP(UK), ECFMG cert.]
# Clinical Researcher
# mHealth Research Group
# nawsabah noor photo-crop-u16973.png
#
# Farhat Binte Azam
# Research Assistant
# mHealth Research Group
# alain bernard labrique.png
#
# Sadia Khan
# Undergraduate Research Student
# mHealth Research Group
# sadia khan-crop-u14717.png
#
# Shoyad Nuhash
# Undergraduate Research Student
# mHealth Research Group
# shoyad nuhash.jpg
#
# Mehnaz Urbee
# Undergraduate Research Student
# mHealth Research Group
# mehnaz urbee.jpg
# ...

# %%
hmm = """<div class="clearfix grpelem" id="ppu2221-4"><!-- column -->
      <div class="clearfix colelem" id="pu2221-4"><!-- group -->
       <div class="clearfix grpelem" id="u2221-4"><!-- content -->
        <p>OUR TEAM:</p>
       </div>
       <div class="size_fixed grpelem" id="u16535"><!-- custom html -->
        

       </div>
      </div>
      <div class="clearfix colelem" id="pu17323"><!-- group -->
       <div class="clearfix grpelem" id="u17323"><!-- group -->
        <a class="nonblock nontext rounded-corners clip_frame grpelem" id="u2208" href="http://bme.buet.ac.bd/?teams=dr-taufiq-hasan"><!-- image --><div class="clip_frame"><img class="block" id="u2208_img" src="images/taufiq-crop-u2208.png?crc=3992161480" alt="" width="120" height="119"></div></a>
        <a class="nonblock nontext clearfix grpelem" id="u2218-10" href="http://bme.buet.ac.bd/?teams=dr-taufiq-hasan"><!-- content --><p id="u2218-2">Dr. Taufiq Hasan</p><p id="u2218-4">Assistant Professor, BME, BUET.</p><p id="u2218-6">Director, mHealth Research Group</p><p id="u2218-8">taufiq@bme.buet.ac.bd</p></a>
       </div>
       <div class="clearfix grpelem" id="u17320"><!-- group -->
        <a class="nonblock nontext rounded-corners clip_frame grpelem" id="u8319" href="http://bme.buet.ac.bd/?teams=dr-imamul-hassan-bhuyian"><!-- image --><div class="clip_frame"><img class="block" id="u8319_img" src="images/imamul_sept19.jpg?crc=202939649" alt="" width="129" height="128"></div></a>
        <a class="nonblock nontext clearfix grpelem" id="u8334-10" href="http://bme.buet.ac.bd/?teams=dr-imamul-hassan-bhuyian"><!-- content --><p id="u8334-2">Dr. Imamul Hassan Bhuiyan</p><p id="u8334-4">Professor & Head, BME, BUET.</p><p id="u8334-6">Professor, EEE, BUET.</p><p id="u8334-8">imamul@eee.buet.ac.bd</p></a>
       </div>
      </div>
      <div class="clearfix colelem" id="pu17248"><!-- group -->
       <div class="clearfix grpelem" id="u17248"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u14605"><!-- image -->
         <div class="clip_frame"><img class="block" id="u14605_img" src="images/sushmit.jpg?crc=73265979" alt="" width="118" height="118"></div>
        </div>
        <div class="clearfix grpelem" id="u14560-8"><!-- content -->
         <p id="u14560-2">Asif Shahriyar</p>
         <p id="u14560-4">Research Assistant</p>
         <p id="u14560-6">mHealth Research Group</p>
        </div>
       </div>
       <div class="clearfix grpelem" id="u17251"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u2229"><!-- image -->
         <div class="clip_frame"><img class="block" id="u2229_img" src="images/_mg_6676-crop-u2229.png?crc=439190146" alt="" width="117" height="120"></div>
        </div>
        <div class="clearfix grpelem" id="u2239-8"><!-- content -->
         <p id="u2239-2">Istiaq Ansari</p>
         <p id="u2239-4">Research Assistant</p>
         <p id="u2239-6">mHealth Research Group</p>
        </div>
       </div>
       <div class="clearfix grpelem" id="u17254"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u16973"><!-- image -->
         <div class="clip_frame"><img class="block" id="u16973_img" src="images/nawsabah%20noor%20photo-crop-u16973.png?crc=15305365" alt="" width="117" height="120"></div>
        </div>
        <div class="clearfix grpelem" id="u16980-10"><!-- content -->
         <p id="u16980-2">Dr. Nawsabah Noor</p>
         <p id="u16980-4">[MBBS, MRCP(UK), ECFMG cert.]</p>
         <p id="u16980-6">Clinical Researcher</p>
         <p id="u16980-8">mHealth Research Group</p>
        </div>
       </div>
      </div>
      <div class="clearfix colelem" id="pu17397"><!-- group -->
       <div class="clearfix grpelem" id="u17397"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u17399"><!-- image -->
         <div class="clip_frame"><img class="block" id="u17399_img" src="images/sindhu%20(1)-crop-u17399.png?crc=370056649" alt="" width="117" height="120"></div>
        </div>
        <div class="clearfix grpelem" id="u17398-8"><!-- content -->
         <p id="u17398-2">Farhat Binte Azam</p>
         <p id="u17398-4">Research Assistant</p>
         <p id="u17398-6">mHealth Research Group</p>
        </div>
       </div>
       <div class="clearfix grpelem" id="u17302"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u14717"><!-- image -->
         <div class="clip_frame"><img class="block" id="u14717_img" src="images/sadia%20khan-crop-u14717.png?crc=3794497525" alt="" width="119" height="119"></div>
        </div>
        <div class="clearfix grpelem" id="u14752-8"><!-- content -->
         <p id="u14752-2">Sadia Khan</p>
         <p id="u14752-4">Undergraduate Research Student</p>
         <p id="u14752-6">mHealth Research Group</p>
        </div>
       </div>
       <div class="clearfix grpelem" id="u17317"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u14727"><!-- image -->
         <div class="clip_frame"><img class="block" id="u14727_img" src="images/shoyad%20nuhash.jpg?crc=354230163" alt="" width="119" height="119"></div>
        </div>
        <div class="clearfix grpelem" id="u14755-8"><!-- content -->
         <p id="u14755-2">Shoyad Nuhash</p>
         <p id="u14755-4">Undergraduate Research Student</p>
         <p id="u14755-6">mHealth Research Group</p>
        </div>
       </div>
      </div>
      <div class="clearfix colelem" id="pu17305"><!-- group -->
       <div class="clearfix grpelem" id="u17305"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u6092"><!-- image -->
         <div class="clip_frame"><img class="block" id="u6092_img" src="images/mehnaz%20urbee.jpg?crc=529199233" alt="" width="120" height="120"></div>
        </div>
        <div class="clearfix grpelem" id="u6108-8"><!-- content -->
         <p id="u6108-2">Mehnaz Urbee</p>
         <p id="u6108-4">Undergraduate Research Student</p>
         <p id="u6108-6">mHealth Research Group</p>
        </div>
       </div>
       <div class="clearfix grpelem" id="u17299"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u14653"><!-- image -->
         <div class="clip_frame"><img class="block" id="u14653_img" src="images/anirban%20chakraborty.jpg?crc=4004046115" alt="" width="119" height="117"></div>
        </div>
        <div class="clearfix grpelem" id="u14758-8"><!-- content -->
         <p id="u14758-2">Anirban Chakraborty</p>
         <p id="u14758-4">Undergraduate Research Student</p>
         <p id="u14758-6">mHealth Research Group</p>
        </div>
       </div>
       <div class="clearfix grpelem" id="u17314"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u14643"><!-- image -->
         <div class="clip_frame"><img class="block" id="u14643_img" src="images/mir%20maheen%20labib.jpg?crc=3808511534" alt="" width="119" height="119"></div>
        </div>
        <div class="clearfix grpelem" id="u14761-8"><!-- content -->
         <p id="u14761-2">Meer Maheen Labib</p>
         <p id="u14761-4">Undergraduate Research Student</p>
         <p id="u14761-6">mHealth Research Group</p>
        </div>
       </div>
      </div>
      <div class="clearfix colelem" id="pu17308"><!-- group -->
       <div class="clearfix grpelem" id="u17308"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u14707"><!-- image -->
         <div class="clip_frame"><img class="block" id="u14707_img" src="images/nurul%20huda.png?crc=451451599" alt="" width="119" height="119"></div>
        </div>
        <div class="clearfix grpelem" id="u14764-8"><!-- content -->
         <p id="u14764-2">Nurul Huda</p>
         <p id="u14764-4">Undergraduate Research Student</p>
         <p id="u14764-6">mHealth Research Group</p>
        </div>
       </div>
       <div class="clearfix grpelem" id="u17296"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u6082"><!-- image -->
         <div class="clip_frame"><img class="block" id="u6082_img" src="images/farhana%20islam.jpg?crc=335319539" alt="" width="129" height="129"></div>
        </div>
        <div class="clearfix grpelem" id="u14767-8"><!-- content -->
         <p id="u14767-2">Farhana Islam</p>
         <p id="u14767-4">Undergraduate Research Student</p>
         <p id="u14767-6">mHealth Research Group</p>
        </div>
       </div>
       <div class="clearfix grpelem" id="u17311"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u14663"><!-- image -->
         <div class="clip_frame"><img class="block" id="u14663_img" src="images/kaisar%20alman.jpg?crc=526518546" alt="" width="119" height="119"></div>
        </div>
        <div class="clearfix grpelem" id="u14770-8"><!-- content -->
         <p id="u14770-2">Kaisar Alman</p>
         <p id="u14770-4">Undergraduate Research Student</p>
         <p id="u14770-6">mHealth Research Group</p>
        </div>
       </div>
      </div>
      <div class="clearfix colelem" id="pu17257"><!-- group -->
       <div class="clearfix grpelem" id="u17257"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u14687"><!-- image -->
         <div class="clip_frame"><img class="block" id="u14687_img" src="images/nusrat%20binta%20nizam.jpg?crc=44605538" alt="" width="119" height="119"></div>
        </div>
        <div class="clearfix grpelem" id="u14746-8"><!-- content -->
         <p id="u14746-2">Nusrat Binta Nizam</p>
         <p id="u14746-4">Undergraduate Research Student</p>
         <p id="u14746-6">mHealth Research Group</p>
        </div>
       </div>
       <div class="clearfix grpelem" id="u17245"><!-- group -->
        <div class="rounded-corners clip_frame grpelem" id="u14677"><!-- image -->
         <div class="clip_frame"><img class="block" id="u14677_img" src="images/meemnur%20rashid.jpg?crc=231512977" alt="" width="119" height="119"></div>
        </div>
        <div class="clearfix grpelem" id="u14749-8"><!-- content -->
         <p id="u14749-2">Meemnur Rashid</p>
         <p id="u14749-4">Undergraduate Research Student</p>
         <p id="u14749-6">mHealth Research Group</p>
        </div>
       </div>
      </div>
      <div class="clearfix colelem" id="u8316-4"><!-- content -->
       <p>ADVISORS:</p>
      </div>
      <div class="clearfix colelem" id="pu8337"><!-- group -->
       <a class="nonblock nontext rounded-corners clip_frame grpelem" id="u8337" href="https://www.jhsph.edu/faculty/directory/profile/1022/alain-bernard-labrique" target="_blank"><!-- image --><div class="clip_frame"><img class="block" id="u8337_img" src="images/pasted%20image%20230x345-crop-u8337.png?crc=140513657" alt="" width="119" height="126"></div></a>
       <a class="nonblock nontext clearfix grpelem" id="u8352-10" href="https://www.jhsph.edu/faculty/directory/profile/1022/alain-bernard-labrique" target="_blank"><!-- content --><p id="u8352-2">Alain Bernard Labrique, PhD</p><p id="u8352-4">Associate Professor</p><p id="u8352-6">Johns Hopkins Bloomberg School of Public Health</p><p id="u8352-8">alabriq1 [AT] jhu.edu</p></a>
       <a class="nonblock nontext rounded-corners clip_frame clearfix grpelem" id="u16015" href="https://www.hopkinsmedicine.org/profiles/results/directory/profile/2936930/paul-nagy" target="_blank"><!-- image --><div class="clip_frame"><img class="position_content" id="u16015_img" src="images/pnagy.jpg?crc=367461501" alt="" width="134" height="134"></div></a>
       <a class="nonblock nontext clearfix grpelem" id="u16045-9" href="https://www.hopkinsmedicine.org/profiles/results/directory/profile/2936930/paul-nagy" target="_blank"><!-- content --><p id="u16045-2">Paul Nagy, PhD</p><p id="u16045-4">Associate Professor</p><p id="u16045-6">Johns Hopkins University School of Medicine</p><p id="u16045-7">&nbsp;</p></a>
      </div>
     </div>
     """
